# %%
import pandas as pd

# %%
# pull every table from the wikipedia page
sen_scrape = pd.read_html('https://en.wikipedia.org/wiki/List_of_current_United_States_senators', attrs = {'id': 'senators'})

sen_scrape[0].head()
# Out:
#      State  Portrait           Senator  Party        Party.1      Born  \
# 0  Alabama       NaN    Richard Shelby    NaN  Republican[2]  (age 87)
# 1  Alabama       NaN  Tommy Tuberville    NaN     Republican  (age 67)
# 2   Alaska       NaN    Lisa Murkowski    NaN     Republican  (age 64)
# 3   Alaska       NaN      Dan Sullivan    NaN     Republican  (age 56)
# 4  Arizona       NaN    Kyrsten Sinema    NaN     Democratic  (age 45)
#
#                                        Occupation(s)  \
# 0                                             Lawyer
# 1  College football coachPartner, investment mana...
# 2                                             Lawyer
# 3  U.S. Marine Corps officerLawyerAssistant Secre...
# 4  Social workerPolitical activistLawyerCollege p...
#
#                           Previous electiveoffice(s)  \
# 0                           U.S. HouseAlabama Senate
# 1                                               None
# 2                    Alaska House of Representatives
# 3                            Alaska Attorney General
# 4  U.S. HouseArizona SenateArizona House of Repre...
#
#                                            Education        Assumed office  \
# 0  University of Alabama Birmingham School of Law...       January 3, 1987
# 1                       Southern Arkansas University       January 3, 2021
# 2  Georgetown University Willamette University Co...  December 20, 2002[d]
# 3  Culver Military Academy Harvard University Geo...       January 3, 2015
# 4                           Brigham Young University       January 3, 2019
#
#    Term up      Residence
# 0     2022  Tuscaloosa[3]
# 1     2026         Auburn
# 2     2022    Girdwood[4]
# 3     2026   Anchorage[5]
# 4     2024     Phoenix[6]

# %%
sen_data = sen_scrape[0][['State', 'Senator', 'Party.1', 'Assumed office', 'Term up']]

state_abbrevs = pd.read_csv("state_abbrevs.csv")
state_pops = pd.read_csv('census20pop.csv',index_col=0)

# %%
# give sen_data an uppercased states column to join with state abbrevs matching col
sen_data['temp_upper'] = sen_data['State'].map(lambda x: x.upper())
sen_data = sen_data.join(state_abbrevs.set_index('states'), on="temp_upper").drop(['temp_upper'], axis=1)

# join with populations
sen_data = sen_data.join(state_pops.set_index('state'), on="State")

# rename
sen_data.rename({'Party.1': 'party', 
                'Assumed office':'assumed_office',
                'Term up': 'term_up'}, inplace = True, axis=1)

# removes all footnotes (of the form [a]) with regex
sen_data.replace("\[\w*\]","", inplace = True, regex = True)


sen_data
# Out:
# /tmp/ipykernel_19377/2610433553.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sen_data['temp_upper'] = sen_data['State'].map(lambda x: x.upper())
#             State               Senator       party     assumed_office  \
# 0         Alabama        Richard Shelby  Republican    January 3, 1987
# 1         Alabama      Tommy Tuberville  Republican    January 3, 2021
# 2          Alaska        Lisa Murkowski  Republican  December 20, 2002
# 3          Alaska          Dan Sullivan  Republican    January 3, 2015
# 4         Arizona        Kyrsten Sinema  Democratic    January 3, 2019
# ..            ...                   ...         ...                ...
# 95  West Virginia  Shelley Moore Capito  Republican    January 3, 2015
# 96      Wisconsin           Ron Johnson  Republican    January 3, 2011
# 97      Wisconsin         Tammy Baldwin  Democratic    January 3, 2013
# 98        Wyoming         John Barrasso  Republican      June 25, 2007
# 99        Wyoming        Cynthia Lummis  Republican    January 3, 2021
#
#     term_up  st  population
# 0      2022  AL     5024279
# 1      2026  AL     5024279
# 2      2022  AK      733391
# 3      2026  AK      733391
# 4      2024  AZ     7151502
# ..      ...  ..         ...
# 95     2026  WV     1793716
# 96     2022  WI     5893718
# 97     2024  WI     5893718
# 98     2024  WY      576851
# 99     2026  WY      576851
#
# [100 rows x 7 columns]

# %% [markdown]
# # Religion

# %%
religion_scrape = pd.read_html("https://en.wikipedia.org/wiki/Religious_affiliation_in_the_United_States_Senate", match="Senator")

# %%
relig_data = religion_scrape[0]

for r in religion_scrape[1:]:
    relig_data = relig_data.append(r, ignore_index = True)

# removes all footnotes (of the form [a]) with regex
relig_data.replace("\[\w*\]","", inplace = True, regex = True)

# GOD DAMN IT WIKIPEDIA
relig_data['Senator'].replace("Bob Casey", "Bob Casey Jr.", inplace=True)
relig_data['Senator'].replace("John Neely Kennedy", "John Kennedy", inplace=True)

relig_data

# TODO: replace some of the terms here with less wordy ones
# Out:
#                  Senator       Party          State  \
# 0       Marsha Blackburn  Republican      Tennessee
# 1          John Barrasso  Republican        Wyoming
# 2   Shelley Moore Capito  Republican  West Virginia
# 3             Tom Carper  Democratic       Delaware
# 4            Chris Coons  Democratic       Delaware
# ..                   ...         ...            ...
# 95          Mazie Hirono  Democratic         Hawaii
# 96         Tammy Baldwin  Democratic      Wisconsin
# 97        Michael Bennet  Democratic       Colorado
# 98       Tammy Duckworth  Democratic       Illinois
# 99        Kyrsten Sinema  Democratic        Arizona
#
#                       Religion  \
# 0                 Presbyterian
# 1                 Presbyterian
# 2                 Presbyterian
# 3                 Presbyterian
# 4                 Presbyterian
# ..                         ...
# 95      Buddhist(Jōdo Shinshū)
# 96  Unknown/Refused to specify
# 97  Unknown/Refused to specify
# 98  Unknown/Refused to specify
# 99                Unaffiliated
#
#                                               Notes
# 0                                               NaN
# 1                                  Former Catholic.
# 2                                               NaN
# 3                                               NaN
# 4                        Attends a Catholic church.
# ..                                              ...
# 95                                  Non-practicing.
# 96                     Baptized as an Episcopalian.
# 97  Raised in both Jewish and Christian traditions.
# 98                 Sometimes acknowledged as Deist.
# 99                    Raised as a Latter-day Saint.
#
# [100 rows x 5 columns]

# %%
relig_data.replace({
    'Buddhist.*': 'Buddhist',
    'Congregationalist.*': 'Congregationalist',
    'Unknown.*': 'Unknown',
    'Holiness.*': 'Holiness',
    'Restorationist.*': 'Restorationist'
}, regex=True, inplace=True)

# %%
sen_data = relig_data[['Senator', 'Religion']].merge(sen_data, on = "Senator", how="outer")
sen_data
# Out:
#                  Senator      Religion          State       party  \
# 0       Marsha Blackburn  Presbyterian      Tennessee  Republican
# 1          John Barrasso  Presbyterian        Wyoming  Republican
# 2   Shelley Moore Capito  Presbyterian  West Virginia  Republican
# 3             Tom Carper  Presbyterian       Delaware  Democratic
# 4            Chris Coons  Presbyterian       Delaware  Democratic
# ..                   ...           ...            ...         ...
# 95          Mazie Hirono      Buddhist         Hawaii  Democratic
# 96         Tammy Baldwin       Unknown      Wisconsin  Democratic
# 97        Michael Bennet       Unknown       Colorado  Democratic
# 98       Tammy Duckworth       Unknown       Illinois  Democratic
# 99        Kyrsten Sinema  Unaffiliated        Arizona  Democratic
#
#        assumed_office  term_up  st  population
# 0     January 3, 2019     2024  TN     6910840
# 1       June 25, 2007     2024  WY      576851
# 2     January 3, 2015     2026  WV     1793716
# 3     January 3, 2001     2024  DE      989948
# 4   November 15, 2010     2026  DE      989948
# ..                ...      ...  ..         ...
# 95    January 3, 2013     2024  HI     1455271
# 96    January 3, 2013     2024  WI     5893718
# 97   January 21, 2009     2022  CO     5773714
# 98    January 3, 2017     2022  IL    12812508
# 99    January 3, 2019     2024  AZ     7151502
#
# [100 rows x 8 columns]

# %% [markdown]
# # Gender

# %%
# sigh. maybe find a better source?
women_senators = pd.read_html("https://en.wikipedia.org/wiki/Women_in_the_United_States_Senate", match="Prior experience")
women_list = list(women_senators[0]['Name'])

# %%
sen_data['gender'] = "Male"

for row in sen_data.iterrows():
    if row[1]['Senator'] in women_list:
        sen_data['gender'].iloc[row[0]] = "Female" # mmmMMM

sen_data
# Out:
# /home/isanford/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                  Senator      Religion          State       party  \
# 0       Marsha Blackburn  Presbyterian      Tennessee  Republican
# 1          John Barrasso  Presbyterian        Wyoming  Republican
# 2   Shelley Moore Capito  Presbyterian  West Virginia  Republican
# 3             Tom Carper  Presbyterian       Delaware  Democratic
# 4            Chris Coons  Presbyterian       Delaware  Democratic
# ..                   ...           ...            ...         ...
# 95          Mazie Hirono      Buddhist         Hawaii  Democratic
# 96         Tammy Baldwin       Unknown      Wisconsin  Democratic
# 97        Michael Bennet       Unknown       Colorado  Democratic
# 98       Tammy Duckworth       Unknown       Illinois  Democratic
# 99        Kyrsten Sinema  Unaffiliated        Arizona  Democratic
#
#        assumed_office  term_up  st  population  gender
# 0     January 3, 2019     2024  TN     6910840  Female
# 1       June 25, 2007     2024  WY      576851    Male
# 2     January 3, 2015     2026  WV     1793716  Female
# 3     January 3, 2001     2024  DE      989948    Male
# 4   November 15, 2010     2026  DE      989948    Male
# ..                ...      ...  ..         ...     ...
# 95    January 3, 2013     2024  HI     1455271  Female
# 96    January 3, 2013     2024  WI     5893718  Female
# 97   January 21, 2009     2022  CO     5773714    Male
# 98    January 3, 2017     2022  IL    12812508  Female
# 99    January 3, 2019     2024  AZ     7151502  Female
#
# [100 rows x 9 columns]

# %%
sen_data['gender'].value_counts()
# Out:
# Male      76
# Female    24
# Name: gender, dtype: int64

# %% [markdown]
# # Race

# %%
sen_data['race'] = "White"

black_senators = ["Cory Booker", 'Tim Scott', 'Raphael Warnock']
asian_senators = ['Mazie Hirono', 'Tammy Duckworth']
hispanic_senators = ['Bob Menendez', 'Marco Rubio', 'Ted Cruz', 'Catherine Cortez Masto', 'Ben Ray Luján', 'Alex Padilla']

for row in sen_data.iterrows():
    if row[1]['Senator'] in black_senators:
        sen_data['race'].iloc[row[0]] = "Black" # mmmMMM
    if row[1]['Senator'] in asian_senators:
        sen_data['race'].iloc[row[0]] = "Asian American" # mmmMMM
    if row[1]['Senator'] in hispanic_senators:
        sen_data['race'].iloc[row[0]] = "Hispanic or Latino" # mmmMMM

print(sen_data['race'].value_counts())
sen_data
# Out:
# White                 89
# Hispanic or Latino     6
# Black                  3
# Asian American         2
# Name: race, dtype: int64
# /home/isanford/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                  Senator      Religion          State       party  \
# 0       Marsha Blackburn  Presbyterian      Tennessee  Republican
# 1          John Barrasso  Presbyterian        Wyoming  Republican
# 2   Shelley Moore Capito  Presbyterian  West Virginia  Republican
# 3             Tom Carper  Presbyterian       Delaware  Democratic
# 4            Chris Coons  Presbyterian       Delaware  Democratic
# ..                   ...           ...            ...         ...
# 95          Mazie Hirono      Buddhist         Hawaii  Democratic
# 96         Tammy Baldwin       Unknown      Wisconsin  Democratic
# 97        Michael Bennet       Unknown       Colorado  Democratic
# 98       Tammy Duckworth       Unknown       Illinois  Democratic
# 99        Kyrsten Sinema  Unaffiliated        Arizona  Democratic
#
#        assumed_office  term_up  st  population  gender            race
# 0     January 3, 2019     2024  TN     6910840  Female           White
# 1       June 25, 2007     2024  WY      576851    Male           White
# 2     January 3, 2015     2026  WV     1793716  Female           White
# 3     January 3, 2001     2024  DE      989948    Male           White
# 4   November 15, 2010     2026  DE      989948    Male           White
# ..                ...      ...  ..         ...     ...             ...
# 95    January 3, 2013     2024  HI     1455271  Female  Asian American
# 96    January 3, 2013     2024  WI     5893718  Female           White
# 97   January 21, 2009     2022  CO     5773714    Male           White
# 98    January 3, 2017     2022  IL    12812508  Female  Asian American
# 99    January 3, 2019     2024  AZ     7151502  Female           White
#
# [100 rows x 10 columns]

# %%
sen_data = sen_data.rename(columns={
    "Senator": "senator",
    "Religion": "religion",
    "State": "state",
    "st": "abbrev"
})
sen_data.head()
# Out:
#                 senator      religion          state       party  \
# 0      Marsha Blackburn  Presbyterian      Tennessee  Republican
# 1         John Barrasso  Presbyterian        Wyoming  Republican
# 2  Shelley Moore Capito  Presbyterian  West Virginia  Republican
# 3            Tom Carper  Presbyterian       Delaware  Democratic
# 4           Chris Coons  Presbyterian       Delaware  Democratic
#
#       assumed_office  term_up abbrev  population  gender   race
# 0    January 3, 2019     2024     TN     6910840  Female  White
# 1      June 25, 2007     2024     WY      576851    Male  White
# 2    January 3, 2015     2026     WV     1793716  Female  White
# 3    January 3, 2001     2024     DE      989948    Male  White
# 4  November 15, 2010     2026     DE      989948    Male  White

# %%
sen_data.to_csv("Senate_Data.csv")
sen_data.to_json("../senate-react/src/data0/senators0.json", orient="records")

# %%
sen_data['religion'].unique()
# Out:
# array(['Presbyterian', 'Baptist', 'Methodist', 'Lutheran', 'Evangelical',
#        'Episcopalian', 'Congregationalist', 'Restorationist', 'Holiness',
#        'Quaker', 'Protestant', 'Catholic', 'Latter-day Saint', 'Jewish',
#        'Buddhist', 'Unknown', 'Unaffiliated'], dtype=object)
